# %% [markdown]
# <a href="https://colab.research.google.com/github/Luis-Martinez-Bautista/daa_2021_1/blob/master/7_diciembre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fnRecInf():
  print("Hola")
  fnRecInf()

# %%
fnRecInf()

# %%
def fnRec(x):
  if x == 0:
    print("Stop")
  else:
    print(x)
    fnRec(x - 1)
def main():
  print("Inicio del programa")
  fnRec(5)
  print("Fin del programa")

main()
# Out:
# Inicio del programa
# 5
# 4
# 3
# 2
# 1
# Stop
# Fin del programa

# %%
def printRev(x):
  if x > 0:
    printRev(x - 1)
    print(x)

printRev(3)
# Out:
# 1
# 2
# 3

# %%
def fibonacci(n):
  print("Llamada: ", n)
  if n == 1 or n == 0:
    return n
  else:
    return (fibonacci(n - 1) + fibonacci(n - 2))
print(fibonacci(20))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Llamada:  0
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# Llamada:  4
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  9
# Llamada:  8
# Llamada:  7
# Llamada:  6
# Llamada:  5
# Llamada:  4
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# Llamada:  4
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  5
# Llamada:  4
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# Llamada:  6
# Llamada:  5
# Llamada:  4
# Llamada:  3
# Llamada:  2
# Llamada:  1
# Llamada:  0
# Llamada:  1
# ...
